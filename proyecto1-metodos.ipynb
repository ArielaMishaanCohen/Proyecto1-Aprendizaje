# %% [markdown]
# # Proyecto 1
# Alina Carías (22539) y Ariela Mishaan (22052)

# %% [markdown]
# ## Librerías

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path
import warnings
warnings.filterwarnings('ignore')

plt.rcParams['figure.dpi'] = 120
sns.set_theme(style='whitegrid', palette='muted')

# %% [markdown]
# ## Carga de archivos

# %%
from pathlib import Path
import pandas as pd

DATA_DIR = Path('/Users/arielamishaancohen/Documentos/Datasets gigantes/Ecobici')
files = sorted(DATA_DIR.glob('*.csv'))

COLS = [
    'Genero_Usuario', 'Edad_Usuario', 'Bici',
    'Ciclo_Estacion_Retiro', 'Fecha_Retiro', 'Hora_Retiro',
    'Ciclo_EstacionArribo', 'Fecha_Arribo', 'Hora_Arribo'
]

dfs = []
errores = []

for f in files:
    try:
        tmp = pd.read_csv(
            f,
            usecols=range(9), # solo las primeras 9 columnas
            names=COLS,
            header=0,
            on_bad_lines='skip',  
            engine='python'
        )
        tmp['_archivo'] = f.name # rastrear el origen
        dfs.append(tmp)
        print(f"OK  {f.name:45s} → {len(tmp):>8,} filas")
    except Exception as e:
        errores.append((f.name, str(e)))
        print(f"ERR {f.name}: {e}")

df = pd.concat(dfs, ignore_index=True)
print(f"\nDataset combinado: {df.shape[0]:,} filas × {df.shape[1]} columnas")
print(f"Archivos cargados: {len(dfs)} / {len(files)}")
if errores:
    print(f"\nArchivos con error: {errores}")
# Out:
# OK  2024-01.csv                                   → 1,467,594 filas
# OK  2024-02.csv                                   → 1,557,176 filas
# OK  2024-03.csv                                   → 1,829,763 filas
# OK  2024-04.csv                                   → 1,961,633 filas
# OK  2024-05.csv                                   → 1,513,369 filas
# OK  2024-06.csv                                   → 1,893,520 filas
# OK  2024-07.csv                                   → 1,065,474 filas
# OK  2024-08.csv                                   → 1,513,016 filas
# OK  2024-09.csv                                   → 1,852,179 filas
# OK  2024-10.csv                                   → 2,054,609 filas
# OK  2024-11.csv                                   → 1,942,474 filas
# OK  2024-12.csv                                   → 1,680,650 filas
# OK  2025-01.csv                                   → 1,809,775 filas
# OK  2025-02.csv                                   → 1,745,620 filas
# ...

# %% [markdown]
# ## Limpieza

# %%
df['Fecha_Retiro'] = pd.to_datetime(df['Fecha_Retiro'], dayfirst=True, errors='coerce')
df['Fecha_Arribo'] = pd.to_datetime(df['Fecha_Arribo'], dayfirst=True, errors='coerce')

# combinar fecha + hora en datetime completo
df['dt_retiro'] = pd.to_datetime(
    df['Fecha_Retiro'].dt.strftime('%Y-%m-%d') + ' ' + df['Hora_Retiro'].astype(str),
    errors='coerce'
)
df['dt_arribo'] = pd.to_datetime(
    df['Fecha_Arribo'].dt.strftime('%Y-%m-%d') + ' ' + df['Hora_Arribo'].astype(str),
    errors='coerce'
)

# %%
# duración del viaje en minutos
df['duracion_min'] = (df['dt_arribo'] - df['dt_retiro']).dt.total_seconds() / 60

# variables temporales útiles
df['anio']          = df['dt_retiro'].dt.year
df['mes']           = df['dt_retiro'].dt.month
df['dia_semana']    = df['dt_retiro'].dt.day_name()
df['hora_retiro']   = df['dt_retiro'].dt.hour

# viaje circular: retiro == arribo
df['es_circular'] = (
    df['Ciclo_Estacion_Retiro'].astype(str) == df['Ciclo_EstacionArribo'].astype(str)
)

# %%
# categoría de género
df['Genero_Usuario'] = df['Genero_Usuario'].str.strip().str.upper()

print(df.dtypes)
print(df['duracion_min'].describe())
# Out:
# Genero_Usuario                   object
# Edad_Usuario                    float64
# Bici                              int64
# Ciclo_Estacion_Retiro            object
# Fecha_Retiro             datetime64[ns]
# Hora_Retiro                      object
# Ciclo_EstacionArribo             object
# Fecha_Arribo             datetime64[ns]
# Hora_Arribo                      object
# _archivo                         object
# dt_retiro                datetime64[ns]
# dt_arribo                datetime64[ns]
# duracion_min                    float64
# anio                            float64
# mes                             float64
# dia_semana                       object
# hora_retiro                     float64
# es_circular                        bool
# dtype: object
# count    4.359236e+07
# mean     1.631390e+01
# std      6.807785e+02
# min      1.666667e-01
# 25%      7.200000e+00
# 50%      1.205000e+01
# 75%      2.006667e+01
# max      1.710731e+06
# ...

# %%
df.head()
# Out:
#   Genero_Usuario  Edad_Usuario     Bici Ciclo_Estacion_Retiro Fecha_Retiro  \
# 0              M          48.0  3371879                   113   2023-12-31
# 1              F          26.0  7033434                   281   2023-12-31
# 2              F          37.0  7169857                   015   2023-12-31
# 3              F          30.0  6368211                   555   2023-12-31
# 4              M          30.0  5136924                   555   2023-12-31
#
#   Hora_Retiro Ciclo_EstacionArribo Fecha_Arribo Hora_Arribo     _archivo  \
# 0    23:21:52                  659   2024-01-01    00:00:02  2024-01.csv
# 1    23:46:02                  047   2024-01-01    00:00:02  2024-01.csv
# 2    23:51:57                  217   2024-01-01    00:00:49  2024-01.csv
# 3    23:53:10                  008   2024-01-01    00:02:39  2024-01.csv
# 4    23:52:53                  008   2024-01-01    00:02:45  2024-01.csv
#
#             dt_retiro           dt_arribo  duracion_min    anio   mes  \
# ...

# %% [markdown]
# ## Descripción general

# %%
print("=== SHAPE ===")
print(df.shape)

print("\n=== TIPOS ===")
print(df.dtypes)

print("\n=== NULOS ===")
nulos = df.isnull().sum()
print(nulos[nulos > 0])
# Out:
# === SHAPE ===
# (43592363, 18)
#
# === TIPOS ===
# Genero_Usuario                   object
# Edad_Usuario                    float64
# Bici                              int64
# Ciclo_Estacion_Retiro            object
# Fecha_Retiro             datetime64[ns]
# Hora_Retiro                      object
# Ciclo_EstacionArribo             object
# Fecha_Arribo             datetime64[ns]
# Hora_Arribo                      object
# _archivo                         object
# dt_retiro                datetime64[ns]
# dt_arribo                datetime64[ns]
# duracion_min                    float64
# anio                            float64
# mes                             float64
# dia_semana                       object
# hora_retiro                     float64
# es_circular                        bool
# dtype: object
#
# === NULOS ===
# Genero_Usuario           113
# Edad_Usuario            1883
# Fecha_Retiro               3
# Ciclo_EstacionArribo       2
# Fecha_Arribo               7
# ...

# %%
print("\n=== DESCRIBE NUMÉRICAS ===")
display(df.describe(include='number').T)

print("\n=== DESCRIBE CATEGÓRICAS ===")
display(df.describe(include='object').T)
# Out:
# === DESCRIBE NUMÉRICAS ===
#                    count          mean           std          min        25%  \
# Edad_Usuario  43590480.0  3.398825e+01  9.755250e+00    16.000000       27.0
# Bici          43592363.0  5.462323e+06  2.027105e+06     7.000000  3722741.0
# duracion_min  43592355.0  1.631390e+01  6.807785e+02     0.166667        7.2
# anio          43592358.0  2.024642e+03  6.677757e-01  2022.000000     2024.0
# mes           43592358.0  6.077559e+00  3.607671e+00     1.000000        3.0
# hora_retiro   43592358.0  1.401464e+01  4.665227e+00     0.000000       10.0
#
#                      50%           75%        max
# Edad_Usuario       32.00  3.900000e+01      160.0
# Bici          5456827.00  7.215288e+06  8999708.0
# duracion_min       12.05  2.006667e+01  1710731.2
# anio             2025.00  2.025000e+03     2026.0
# mes                 6.00  9.000000e+00       12.0
# hora_retiro        14.00  1.800000e+01       23.0
# === DESCRIBE CATEGÓRICAS ===
# ...

# %%
print("\n=== RANGO TEMPORAL ===")
print(f"  Primer viaje : {df['dt_retiro'].min()}")
print(f"  Último viaje : {df['dt_retiro'].max()}")
print(f"  Años únicos  : {sorted(df['anio'].dropna().unique().astype(int))}")

print("\n=== DISTRIBUCIÓN DE GÉNERO ===")
print(df['Genero_Usuario'].value_counts(dropna=False))
# Out:
# === RANGO TEMPORAL ===
#   Primer viaje : 2022-08-19 14:44:45
#   Último viaje : 2026-03-31 23:55:39
#   Años únicos  : [2022, 2023, 2024, 2025, 2026]
#
# === DISTRIBUCIÓN DE GÉNERO ===
# Genero_Usuario
# M      29852978
# F      12300492
# O        834173
# ?        604607
# NaN         113
# Name: count, dtype: int64

# %% [markdown]
# ### Valores faltantes y duplicados

# %%
# Calcula el porcentaje de nulos por columna
null_counts = df.isnull().sum() / len(df) * 100

# Grafica solo las columnas que tienen nulos
null_counts[null_counts > 0].plot(kind='barh', color='salmon')
plt.title("Porcentaje de valores faltantes por columna")
plt.xlabel("% de Nulos")
plt.show()

# %%
pct_nulos = (df.isnull().mean() * 100).round(2)
print(pct_nulos[pct_nulos > 0].sort_values(ascending=False).to_string())
# Out:
# Series([], )

# %%
n_dup = df.duplicated().sum()
print(f"\nFilas duplicadas: {n_dup:,} ({n_dup/len(df)*100:.2f}%)")
# Out:
# Filas duplicadas: 0 (0.00%)

# %%
mask_bad = (df['duracion_min'] <= 0) | (df['duracion_min'] > 1440)
print(f"Duraciones fuera de rango: {mask_bad.sum():,}")
# Out:
# Duraciones fuera de rango: 1,181

# %% [markdown]
# ## Análisis exploratorio

# %%
df_clean = df[
    (df['duracion_min'] > 0) &
    (df['duracion_min'] <= 180)  
].copy()

# %% [markdown]
# ### Viajes por año

# %%
df_clean['mes'].value_counts().sort_index().plot.bar()
plt.title("Viajes por mes")
plt.xlabel("Mes")
plt.ylabel("Número de viajes")
plt.show()

# %% [markdown]
# ### Viajes por hora del día

# %%
df_clean.groupby('hora_retiro').size().plot()
plt.title("Viajes por hora del día")
plt.xlabel("Hora")
plt.ylabel("Número de viajes")
plt.show()

# %% [markdown]
# ### Distrinución de duración

# %%
df_clean['duracion_min'].sample(200000).hist(bins=60)
plt.title("Distribución de duración (min)")
plt.xlabel("Minutos")
plt.show()

# %% [markdown]
# ### Distribución de edad

# %%
df_clean['Edad_Usuario'].dropna().sample(200000).hist(bins=40)
plt.title("Distribución de edad")
plt.xlabel("Edad")
plt.show()

# %% [markdown]
# ### Viajes por día de la semana

# %%
orden_dias = ['Monday','Tuesday','Wednesday','Thursday','Friday','Saturday','Sunday']

df_clean['dia_semana'].value_counts().reindex(orden_dias).plot.bar()
plt.title("Viajes por día de la semana")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### Proporción de género

# %%
df_clean['Genero_Usuario'].value_counts().plot.pie(autopct='%1.1f%%')
plt.title("Distribución de género")
plt.ylabel("")
plt.show()

# %% [markdown]
# ### Hora vs día

# %%
pivot = df_clean.groupby(['dia_semana','hora_retiro']).size().unstack()

import seaborn as sns
sns.heatmap(pivot, cmap="viridis")
plt.title("Patrón de uso (día vs hora)")
plt.show()

# %% [markdown]
# ### Análisis de estaciones

# %% [markdown]
# #### Top 5 estaciones con más retiros

# %%
top_retiro = (
    df_clean['Ciclo_Estacion_Retiro']
    .value_counts()
    .head(15)
)

top_arribo = (
    df_clean['Ciclo_EstacionArribo']
    .value_counts()
    .head(15)
)

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 5))

top_retiro.plot.barh(ax=ax1, color='steelblue', edgecolor='none')
ax1.invert_yaxis()
ax1.set_title("Top 15 estaciones — retiro")
ax1.set_xlabel("viajes")

top_arribo.plot.barh(ax=ax2, color='#1D9E75', edgecolor='none')
ax2.invert_yaxis()
ax2.set_title("Top 15 estaciones — arribo")
ax2.set_xlabel("viajes")

plt.tight_layout()
plt.show()

# %% [markdown]
# #### Balance neto por estación

# %%
retiros = df_clean['Ciclo_Estacion_Retiro'].value_counts()
arribos = df_clean['Ciclo_EstacionArribo'].value_counts()
balance = (retiros - arribos).dropna().sort_values()

print("Estaciones con más SALIDAS netas (fuente):")
print(balance.tail(10))
print("\nEstaciones con más ENTRADAS netas (sumidero):")
print(balance.head(10))
# Out:
# Estaciones con más SALIDAS netas (fuente):
# 022        17639
# 494        17847
# 711        18606
# 465        18852
# 235-236    23624
# 495        24300
# 211        27062
# 192-193    34656
# 208        35163
# 237-238    52919
# Name: count, dtype: int64
#
# Estaciones con más ENTRADAS netas (sumidero):
# 271-272   -245133
# 014        -99397
# 266-267    -56372
# 043        -32419
# 273-274    -25694
# 029        -25008
# 217        -21957
# 260        -19781
# 134        -19085
# 548        -18229
# Name: count, dtype: int64

# %% [markdown]
# ### Correlaciones y selección de variables

# %% [markdown]
# #### Features númericas

# %%
num_cols = ['Edad_Usuario', 'duracion_min', 'hora_retiro', 'mes']

fig, ax = plt.subplots(figsize=(6, 5))
sns.heatmap(
    df_clean[num_cols].corr(),
    annot=True, fmt='.2f',
    cmap='RdBu_r', center=0,
    linewidths=0.5, ax=ax
)
ax.set_title("Correlaciones — variables numéricas")
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Pairplot

# %%
sample = df_clean[num_cols + ['Genero_Usuario']].dropna().sample(5000, random_state=42)
sns.pairplot(sample, hue='Genero_Usuario', plot_kws={'alpha': 0.3, 's': 10})
plt.suptitle("Pairplot — muestra 5 000 viajes", y=1.01)
plt.show()

# %% [markdown]
# ### Análisis de las estaciones (API)

# %%
import requests
import pandas as pd

# URL de estaciones
url = "https://gbfs.mex.lyftbikes.com/gbfs/en/station_information.json"

# request
res = requests.get(url)
data = res.json()

# extraer estaciones
stations = data['data']['stations']

# dataframe
df_stations = pd.DataFrame(stations)

# ver columnas
print(df_stations.columns)
df_stations.head()
# Out:
# Index(['station_id', 'external_id', 'name', 'short_name', 'lat', 'lon',
#        'rental_methods', 'capacity', 'electric_bike_surcharge_waiver',
#        'is_charging', 'eightd_has_key_dispenser', 'has_kiosk'],
#       dtype='object')
#   station_id                           external_id  \
# 0          1  e961269c-34c4-4b70-8e30-a51aa95a8429
# 1          5  3ea89109-d2f3-46eb-9c41-c43742050340
# 2          6  ba78b703-4e5a-44bd-ab2c-1eedc71e11c3
# 3          7  6563d263-2342-46e3-8983-461e68d2d615
# 4          8  ec55e597-c8fc-4e86-bcfe-b0e81a494790
#
#                                                 name short_name        lat  \
# 0     CE-710 Molino del Rey - Glorieta de la Lealtad        710  19.416795
# 1  CE-407  Prolongación Xochicalco-General Emilia...        407  19.367266
# 2  CE-428  Prolongación Uxmal-Av. Popocatépetl (E...        428  19.363404
# 3  CE-427 Avenida México-Coyoacán-Av. Popocatépet...        427  19.364906
# ...

# %% [markdown]
# #### Mapa simple

# %%
# Mapa simple
import matplotlib.pyplot as plt

plt.scatter(df_stations['lon'], df_stations['lat'], s=10, alpha=0.6)

plt.title("Ubicación de estaciones ECOBICI")
plt.xlabel("Longitud")
plt.ylabel("Latitud")
plt.show()

# %% [markdown]
# #### Mapa de densidad de las estaciones

# %%
import seaborn as sns

sns.kdeplot(
    x=df_stations['lon'],
    y=df_stations['lat'],
    fill=True,
    cmap="viridis",
    bw_adjust=0.5
)

plt.title("Densidad de estaciones ECOBICI")
plt.show()

# %% [markdown]
# #### Distribución de capacidad de las estaciones

# %%
# distribución de capacidad
df_stations['capacity'].hist(bins=30)

plt.title("Distribución de capacidad por estación")
plt.xlabel("Capacidad")
plt.ylabel("Frecuencia")
plt.show()

# %% [markdown]
# #### Mapa con tamaño proporcional

# %%
# mapa con tamaño proporcional

plt.scatter(
    df_stations['lon'],
    df_stations['lat'],
    s=df_stations['capacity'],  # tamaño
    alpha=0.5
)

plt.title("Estaciones (tamaño ~ capacidad)")
plt.xlabel("Longitud")
plt.ylabel("Latitud")
plt.show()

# %% [markdown]
# ### Estaciones vs viajes

# %%
df_merged = df_clean.merge(
    df_stations[['station_id','lat','lon']],
    left_on='Ciclo_Estacion_Retiro',
    right_on='station_id',
    how='left'
)

# %%
df_merged = df_merged.merge(
    df_stations[['station_id','lat','lon']],
    left_on='Ciclo_EstacionArribo',
    right_on='station_id',
    how='left',
    suffixes=('_retiro', '_arribo')
)

# %% [markdown]
# #### Mapa de viajes

# %%
sample = df_merged.sample(50000)  # para que no explote

plt.scatter(sample['lon_retiro'], sample['lat_retiro'], s=1, alpha=0.3)

plt.title("Mapa de viajes (puntos de retiro)")
plt.xlabel("Longitud")
plt.ylabel("Latitud")
plt.show()

# %% [markdown]
# #### Mapa de densidad (hotspots)

# %%
import seaborn as sns

sample = df_merged.sample(50000)

sns.kdeplot(
    x=sample['lon_retiro'],
    y=sample['lat_retiro'],
    fill=True,
    cmap="viridis",
    bw_adjust=0.4
)

plt.title("Densidad de viajes (hotspots)")
plt.show()

# %% [markdown]
# #### Mapa de origen a destino (trayectorias)

# %%
sample = df_merged.sample(5000)

for _, row in sample.iterrows():
    plt.plot(
        [row['lon_retiro'], row['lon_arribo']],
        [row['lat_retiro'], row['lat_arribo']],
        alpha=0.05,
        color='blue'
    )

plt.title("Trayectorias de viajes")
plt.xlabel("Longitud")
plt.ylabel("Latitud")
plt.show()

# %% [markdown]
# #### Duración de viaje promedio por zona

# %%
df_zone = df_merged.groupby('Ciclo_Estacion_Retiro').agg({
    'duracion_min': 'mean'
}).reset_index()

df_zone = df_zone.merge(
    df_stations[['station_id','lat','lon']],
    left_on='Ciclo_Estacion_Retiro',
    right_on='station_id'
)

plt.scatter(
    df_zone['lon'],
    df_zone['lat'],
    c=df_zone['duracion_min'],
    cmap='coolwarm',
    s=50
)

plt.colorbar(label='Duración promedio')
plt.title("Duración promedio por estación")
plt.show()

# %% [markdown]
# ## Selección de Variables

# %% [markdown]
# ### Correlación

# %%
vars_num = ['duracion_min','Edad_Usuario','hora_retiro','lat_retiro','lon_retiro']

corr = df_merged[vars_num].corr()

sns.heatmap(corr, annot=True, cmap='coolwarm')
plt.title("Matriz de correlación")
plt.show()

# %% [markdown]
# Variables muy correlacionadas son redundantes. Poco relacionadas aportan información nueva. Como las variables no están correlacionadas --> todas las variables numéricas son significativas.

# %% [markdown]
# ### Información Mutua

# %%
from sklearn.feature_selection import mutual_info_regression

# Tomamos una muestra aleatoria para acelerar el cálculo
df_sample = df_merged.sample(n=50000, random_state=42)

X_sample = df_sample[['hora_retiro','Edad_Usuario','lat_retiro','lon_retiro']].dropna()
y_sample = df_sample.loc[X_sample.index, 'duracion_min']

# Esto debería tardar segundos ahora
mi = mutual_info_regression(X_sample, y_sample)

pd.Series(mi, index=X.columns).sort_values().plot.barh()
plt.title("Importancia (Mutual Information)")
plt.show()

# %% [markdown]
# Mide cuánta ifnormación aporta cada variable. Mejor que correlación para relaciones complejas.

# %% [markdown]
# ### LASSO (selección automática)

# %%
from sklearn.linear_model import Lasso
from sklearn.preprocessing import StandardScaler

# 1. Creamos la muestra primero (ej. 100,000 filas)
# Usamos random_state para que el resultado sea siempre el mismo
df_sample = df_merged.sample(n=100000, random_state=42)

# 2. Definimos X e y sobre la muestra
X_sample = df_sample[['hora_retiro','Edad_Usuario','lat_retiro','lon_retiro']].dropna()
y_sample = df_sample.loc[X_sample.index, 'duracion_min']

# 3. Escalamos los datos (Crítico para que LASSO funcione bien)
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X_sample)

# 4. Entrenamos el modelo
model = Lasso(alpha=0.1)
model.fit(X_scaled, y_sample)

# 5. Graficamos
pd.Series(model.coef_, index=X_sample.columns).sort_values().plot.barh()
plt.axvline(0, color='black', linestyle='--', linewidth=0.8) # Línea de referencia en cero
plt.title("Coeficientes LASSO (Muestra de 100k)")
plt.xlabel("Peso del coeficiente")
plt.show()

# %% [markdown]
# ## Métodos estadísticos

# %% [markdown]
# **PREGUNTA: solo se están usando pocas variables, ver si se puede incluir más o por qué no lo estamos haciendo de una vez.**

# %%
# sacar muestra para que sea más eficiente

# 1. Definir variables y tomar muestra (100k - 200k es ideal)
vars_pca = ['duracion_min', 'Edad_Usuario', 'hora_retiro', 'lat_retiro', 'lon_retiro']
df_sample = df_merged[vars_pca].dropna().sample(n=100000, random_state=42)

# 2. Escalar los datos de la muestra
scaler = StandardScaler()
X_scaled_sample = scaler.fit_transform(df_sample)

# %% [markdown]
# ### PCA (Análisis de componentes principales)

# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# 3. Ajustar el PCA solo con la muestra
pca = PCA()
pca.fit(X_scaled_sample)

# 4. (Opcional) Si necesitas transformar TODOS los datos después:
# X_full_scaled = scaler.transform(df_merged[vars_pca].dropna()) # Cuidado con la RAM
# X_pca_full = pca.transform(X_full_scaled)
# Out:
# PCA()

# %%
# 5. Visualizar la Varianza Explicada (Esto es lo más importante del PCA)
import matplotlib.pyplot as plt
import numpy as np

plt.bar(range(1, len(pca.explained_variance_ratio_) + 1), pca.explained_variance_ratio_)
plt.step(range(1, len(pca.explained_variance_ratio_) + 1), np.cumsum(pca.explained_variance_ratio_), where='mid', color='red')
plt.title("Varianza Explicada por Componente")
plt.xlabel("Componente Principal")
plt.ylabel("Ratio de Varianza")
plt.show()

# %%
pd.DataFrame(pca.components_, columns=vars_pca)
# Out:
#    duracion_min  Edad_Usuario  hora_retiro  lat_retiro  lon_retiro
# 0      0.172689      0.128145     0.215692    0.678017   -0.668975
# 1      0.360883     -0.614114     0.688035   -0.101914    0.094068
# 2      0.824750      0.521144    -0.010985   -0.133297    0.174088
# 3     -0.399237      0.573267     0.689375   -0.041300    0.187165
# 4      0.018394     -0.078843    -0.068747    0.714446    0.691583

# %% [markdown]
# FALTA: esto es para hacer la interpretación de componentes.

# %% [markdown]
# ### Clustering K-Means

# %%
from sklearn.cluster import KMeans

kmeans = KMeans(n_clusters=5)
clusters = kmeans.fit_predict(X_scaled)

# %%
inertia = []
for k in range(1,10):
    km = KMeans(n_clusters=k).fit(X_scaled)
    inertia.append(km.inertia_)

plt.plot(range(1,10), inertia)
plt.title("Método del codo")
plt.show()

# %% [markdown]
# ### Clustering jerárquico

# %%
from scipy.cluster.hierarchy import dendrogram, linkage

Z = linkage(X_scaled, method='ward')

dendrogram(Z)
plt.title("Dendrograma")
plt.show()
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
